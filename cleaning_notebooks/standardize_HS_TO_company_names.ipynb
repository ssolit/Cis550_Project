# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /opt/anaconda3/lib/python3.8/site-packages (0.18.0)

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
companies_to = pd.read_csv("../cleaned_data/TO_Previews_Companies.csv", lineterminator='\n')[["CompanyName"]]
companies_hs = pd.read_csv("../cleaned_data/handshake_jobs.csv", lineterminator='\n')[['employer_name']].drop_duplicates()

# %%
companies_to
# Out:
#                     CompanyName
# 0      Oltmans Construction Co.
# 1                    Humanetics
# 2                 Together Labs
# 3              The Conair Group
# 4                    FortunaPIX
# ...                         ...
# 42026                  AjnaLens
# 42027               nCore Games
# 42028                  HashCube
# 42029      99 Ecommerce Experts
# 42030                  Simnovus
#
# [42031 rows x 1 columns]

# %%
companies_hs
# Out:
#                        employer_name
# 0                           Manifold
# 2               JPMorgan Chase & Co.
# 3                                IBM
# 8               Hudson River Trading
# 9                         Five Rings
# ...                              ...
# 37792                Mastery Schools
# 37795          Intercommunity Action
# 37799                   Camp Olympia
# 37801                      100KIDEAS
# 37802  Robinson Aviation (RVA), Inc.
#
# [6190 rows x 1 columns]

# %%
match_df = pd.merge(companies_hs, companies_to, left_on="employer_name", right_on="CompanyName")
match_df
# Out:
#              employer_name            CompanyName
# 0                 Manifold               Manifold
# 1              Uncountable            Uncountable
# 2                Instabase              Instabase
# 3                    Glean                  Glean
# 4                  PreVeil                PreVeil
# ..                     ...                    ...
# 411                 Accion                 Accion
# 412              WellPower              WellPower
# 413           GiveDirectly           GiveDirectly
# 414                  Dutch                  Dutch
# 415  Intercommunity Action  Intercommunity Action
#
# [416 rows x 2 columns]

# %%
unmatched_hs = pd.merge(companies_hs, companies_to, left_on="employer_name", right_on="CompanyName", how="left").fillna("")
unmatched_hs = unmatched_hs[unmatched_hs["CompanyName"] == ""][["employer_name"]]
unmatched_hs
# Out:
#                       employer_name
# 1              JPMorgan Chase & Co.
# 2                               IBM
# 3              Hudson River Trading
# 4                        Five Rings
# 5                   Bank of America
# ...                             ...
# 6185              Bryn Mawr College
# 6186                Mastery Schools
# 6188                   Camp Olympia
# 6189                      100KIDEAS
# 6190  Robinson Aviation (RVA), Inc.
#
# [5775 rows x 1 columns]

# %%
unmatched_hs = pd.merge(companies_hs, companies_to, how="cross")
unmatched_hs
# Out:
#                            employer_name               CompanyName
# 0                               Manifold  Oltmans Construction Co.
# 1                               Manifold                Humanetics
# 2                               Manifold             Together Labs
# 3                               Manifold          The Conair Group
# 4                               Manifold                FortunaPIX
# ...                                  ...                       ...
# 260171885  Robinson Aviation (RVA), Inc.                  AjnaLens
# 260171886  Robinson Aviation (RVA), Inc.               nCore Games
# 260171887  Robinson Aviation (RVA), Inc.                  HashCube
# 260171888  Robinson Aviation (RVA), Inc.      99 Ecommerce Experts
# 260171889  Robinson Aviation (RVA), Inc.                  Simnovus
#
# [260171890 rows x 2 columns]

# %%
unmatched_hs['ratio'] = unmatched_hs.apply(lambda row: fuzz.ratio(row['employer_name'], row['CompanyName']), axis=1)

# %%
unmatched_hs
# Out:
#                            employer_name               CompanyName  ratio
# 0                               Manifold  Oltmans Construction Co.     25
# 1                               Manifold                Humanetics     33
# 2                               Manifold             Together Labs     10
# 3                               Manifold          The Conair Group     25
# 4                               Manifold                FortunaPIX     11
# ...                                  ...                       ...    ...
# 260171885  Robinson Aviation (RVA), Inc.                  AjnaLens     11
# 260171886  Robinson Aviation (RVA), Inc.               nCore Games     10
# 260171887  Robinson Aviation (RVA), Inc.                  HashCube      5
# 260171888  Robinson Aviation (RVA), Inc.      99 Ecommerce Experts      8
# 260171889  Robinson Aviation (RVA), Inc.                  Simnovus     11
#
# [260171890 rows x 3 columns]

# %%
unmatched_hs.to_csv("unmatched_hs_all_ratios.csv")

# %%
mini = unmatched_hs.iloc[0:100000]

# %%
max_ratio = unmatched_hs.groupby("employer_name").agg({'ratio': max}).reset_index()
max_ratio = pd.merge(max_ratio, unmatched_hs, on=["employer_name", "ratio"])
max_ratio
# Out:
#                            employer_name  ratio        CompanyName
# 0                          1 Atelier LLC     64       Advenser LLC
# 1                              100KIDEAS     57              10xDS
# 2                             1047 Games    100         1047 Games
# 3                       121 Concepts NYC     67        GO Concepts
# 4                           137 Ventures    100       137 Ventures
# ...                                  ...    ...                ...
# 8145                 tutor@air-class.com     55         iTutor.com
# 8146                             wikiHow    100            wikiHow
# 8147         www.teachenglishinkorea.org     47   Tango Publishing
# 8148  “A Platform that Shares!”- TripleE     51  Platform Ventures
# 8149                    宽德投资 WizardQuant     55             Wizard
#
# [8150 rows x 3 columns]

# %%
max_ratio.to_csv("max_ratio_matches_companies.csv")

# %%
fuzzy_matches = max_ratio[max_ratio["ratio"] > 90]
fuzzy_matches = fuzzy_matches[fuzzy_matches["ratio"] < 100]
fuzzy_matches.to_csv("max_ratio_matches_90_99.csv")

# %%
# From here, I manually evaluated the fuzzy matches -- many were not true matches

# %%
# Finally, create the full table of matching TO and HS company names
fuzzy_matches_manual = pd.read_csv("../cleaned_data/fuzzy_matches_manual.csv")
fuzzy_matches_manual
# Out:
#     Unnamed: 0                                  employer_name  \
# 0          477           Analytical Mechanics Associates, Inc
# 1          824      Baptist Children's Home of North Carolina
# 2          835                     Barton & Loguidice, D.P.C.
# 3         1163                                C16 Biosciences
# 4         1412                    Carney, Sandoe & Associates
# 5         1755                               Coding with Kids
# 6         2074                                       DMC Inc.
# 7         2547                                   Estuate, Inc
# 8         2643               Farallon Capital Management, LLC
# 9         3032                        Goliath Technologies LP
# 10        3110                               Greener Partners
# 11        3162                               H2Ok Innovations
# 12        3229                              Harris Associates
# 13        3236                            Hartree Partners LP
# 14        3893  Kentucky Community & Technical College System
# 15        3949                               Kobre & Kim, LLP
# 16        4866         National Endowment for Democracy (NED)
# 17        5426                 Pathway Capital Management, LP
# 18        6625                             StepStone Group LP
# 19        6703                  SummitWorks Technologies Inc.
# 20        6980               The Center for American Progress
# 21        7291                  Trinity Health Of New England
# 22        7472                  Union of Concerned Scientists
# 23        7860                 Westside Family Healthcare Inc
#
#                                         CompanyName  ratio
# 0                   Analytical Mechanics Associates     93
# 1        Baptist Children's Homes of North Carolina     99
# 2                          Barton & Loguidice, P.C.     96
# 3                                   c16 Biosciences     93
# 4                        Carney Sandoe & Associates     98
# 5                                  Coding With Kids     94
# 6                                         DMC, Inc.     94
# 7                                     Estuate, Inc.     96
# 8                       Farallon Capital Management     92
# 9                              Goliath Technologies     93
# 10                              Greenbrier Partners     91
# 11                                   H2O Innovation     93
# 12                              Harris & Associates     94
# 13                                 Hartree Partners     91
# 14  Kentucky Community and Technical College System     96
# 15                                  Kobre & Kim LLP     97
# 16                 National Endowment for Democracy     91
# 17                       Pathway Capital Management     93
# 18                                  StepStone Group     91
# 19                         SummitWorks Technologies     91
# 20                     Center for American Progress     93
# 21                    Trinity Health of New England     97
# 22                    Union Of Concerned Scientists     97
# 23                       Westside Family Healthcare     93

# %%
full_matches = pd.concat([fuzzy_matches_manual, match_df]).fillna(100).rename(columns={'employer_name': 'CompanyNameHS', 'CompanyName': 'CompanyNameTO'})
full_matches = full_matches[['CompanyNameHS', 'CompanyNameTO']]
full_matches
# Out:
#                                  CompanyNameHS  \
# 0         Analytical Mechanics Associates, Inc
# 1    Baptist Children's Home of North Carolina
# 2                   Barton & Loguidice, D.P.C.
# 3                              C16 Biosciences
# 4                  Carney, Sandoe & Associates
# ..                                         ...
# 411                                     Accion
# 412                                  WellPower
# 413                               GiveDirectly
# 414                                      Dutch
# 415                      Intercommunity Action
#
#                                   CompanyNameTO
# 0               Analytical Mechanics Associates
# 1    Baptist Children's Homes of North Carolina
# 2                      Barton & Loguidice, P.C.
# 3                               c16 Biosciences
# 4                    Carney Sandoe & Associates
# ..                                          ...
# 411                                      Accion
# 412                                   WellPower
# 413                                GiveDirectly
# 414                                       Dutch
# 415                       Intercommunity Action
#
# [440 rows x 2 columns]

# %%
full_matches.to_csv("../cleaned_data/HS_TO_company_names_conversion.csv")

# %% [markdown]
# ## Merge and fix TO company names to match handshake ones

# %%
full_matches = pd.read_csv("../cleaned_data/HS_TO_company_names_conversion.csv", lineterminator='\n').drop(columns=["Unnamed: 0"])
company_to = pd.read_csv("../cleaned_data/to_companies.csv", lineterminator='\n').drop(columns=["Unnamed: 0", "Unnamed: 0.1"])
company_to = pd.merge(company_to, full_matches, left_on="CompanyName", right_on="CompanyNameTO")
company_to["CompanyName"] = company_to.apply(lambda row: row["CompanyNameHS"] if row["CompanyNameHS"] is not None else row["CompanyName"], axis=1)
company_to.to_csv("../cleaned_data/to_companies_names_fixed.csv")
company_to
# Out:
#                   CompanyName                          twitterUrl  \
# 0              Bowery Farming   https://twitter.com/BoweryFarming
# 1                  FiscalNote      https://twitter.com/FiscalNote
# 2                    Allbirds        https://twitter.com/allbirds
# 3        GDS Associates, Inc.   https://twitter.com/GDSassociates
# 4                Cooper Carry     https://twitter.com/CooperCarry
# ..                        ...                                 ...
# 437  Aldrich Capital Partners  https://twitter.com/AldrichCapital
# 438                     Dutch  https://twitter.com/DutchPetHealth
# 439                Dreamhaven   https://twitter.com/DreamhavenEnt
# 440                1047 Games       https://twitter.com/Splitgate
# 441                   Caravan                                 NaN
#
#                                            linkedInUrl  \
# 0      https://www.linkedin.com/company/bowery-farming
# 1           http://www.linkedin.com/company/fiscalnote
# 2               https://linkedin.com/company/allbirds/
# 3    https://www.linkedin.com/company/gds-associate...
# 4        https://www.linkedin.com/company/cooper-carry
# ..                                                 ...
# 437  https://linkedin.com/company/aldrich-capital-p...
# 438          https://www.linkedin.com/company/dutchpet
# 439       https://www.linkedin.com/company/dreamhaven/
# 440        https://www.linkedin.com/company/1047games/
# 441  https://www.linkedin.com/company/caravan-digit...
#
#                                            facebookUrl  \
# 0                   https://facebook.com/boweryfarming
# 1                      https://facebook.com/fiscalnote
# 2                   https://facebook.com/weareallbirds
# 3        https://www.facebook.com/gdsenergyconsultants
# 4    https://www.facebook.com/pages/Cooper-Carry-Th...
# ..                                                 ...
# 437              https://facebook.com/1469198223358728
# 438                      http://facebook.com/dutchpet/
# 439                                                NaN
# 440                                                NaN
# 441                                                NaN
#
#                          websiteUrl           city        country  \
# 0          http://boweryfarming.com       New York  United States
# 1         http://www.fiscalnote.com     Washington  United States
# 2         https://www.allbirds.com/  San Francisco  United States
# 3    https://www.gdsassociates.com/       Marietta  United States
# 4      https://www.coopercarry.com/        Atlanta  United States
# ..                              ...            ...            ...
# 437           http://aldrichcap.com         Vienna  United States
# 438           https://www.dutch.com        Oakland  United States
# 439     https://www.dreamhaven.com/         Irvine  United States
# 440            http://1047games.com    Zephyr Cove  United States
# 441       https://hellocaravan.com/      Vancouver         Canada
#
#                                       locationString employeeSizeRange  \
# 0                  New York, New York, United States           200-500
# 1    Washington, District of Columbia, United States           200-500
# 2           San Francisco, California, United States           200-500
# 3                   Marietta, Georgia, United States           200-500
# 4                    Atlanta, Georgia, United States           200-500
# ..                                               ...               ...
# 437                  Vienna, Virginia, United States             10-50
# 438               Oakland, California, United States             10-50
# 439                Irvine, California, United States             10-50
# 440               Zephyr Cove, Nevada, United States             10-50
# 441                            Vancouver, BC, Canada             10-50
#
#                                            description state  \
# 0    Bowery's headquarters are based in Manhattan. ...   NaN
# 1    FiscalNote is the premier information services...   NaN
# 2    Allbirds is a San Francisco-based startup aime...   NaN
# 3    GDS Associates, Inc. Engineers and Consultants...   NaN
# 4    Cooper Carry is one of America's most dynamic,...   NaN
# ..                                                 ...   ...
# 437  Aldrich Capital Partners (“ACP”) is a middle-m...   NaN
# 438  Dutch is revolutionizing the American veterina...   NaN
# 439  Dreamhaven is a new video game developer and p...   NaN
# 440  1047 Games is an independent development studi...   NaN
# 441  Caravan is a team of creatives and technologis...    BC
#
#                 CompanyNameHS             CompanyNameTO
# 0              Bowery Farming            Bowery Farming
# 1                  FiscalNote                FiscalNote
# 2                    Allbirds                  Allbirds
# 3        GDS Associates, Inc.      GDS Associates, Inc.
# 4                Cooper Carry              Cooper Carry
# ..                        ...                       ...
# 437  Aldrich Capital Partners  Aldrich Capital Partners
# 438                     Dutch                     Dutch
# 439                Dreamhaven                Dreamhaven
# 440                1047 Games                1047 Games
# 441                   Caravan                   Caravan
#
# [442 rows x 13 columns]
